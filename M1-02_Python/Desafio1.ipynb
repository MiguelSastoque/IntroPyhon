# %% [markdown]
# # *DESAFIO 1*
# Escriba una Función que dados dos números enteros encuentre el máximo común divisor utilizando para ello conjuntos, listas, controles de flujo y ciclos

# %%
def mcd(num1, num2):
  mcd = 0
  return mcd

# %%
mcd(12,9)
