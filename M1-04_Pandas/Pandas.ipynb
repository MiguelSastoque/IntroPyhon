# %% [markdown]
# # 1. Introducción a Pandas

# %% [markdown]
# ## ¿Qué es pandas?
# Es una librería de análisis de datos que se compone de una serie de estructuras de datos con funcionalidades para limpiar, analizar y preprocesar los datos para tareas siguientes al análisis.
#
# ![wget](https://drive.google.com/uc?export=view&id=1mbFgZLmt0qD80FleVEj4cpxh5oO3ocvQ)

# %% [markdown]
# ## Importando pandas
# Pandas se puede importar de la siguiente manera. Se utiliza el nombre pd por facilidad de manejo.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
# Una serie es un arreglo unidimensional con un índice correspondiente a cada posición del arreglo. Por ejemplo, el listado de jugadores de un equipo, donde el arreglo tiene los apellidos de los jugadores y el índice el número del jugador.

# %%
seleccionColombia = pd.Series(
    ['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'], 
    index=[1, 2, 9, 11, 10])

# %% [markdown]
# Como se puede observar con los jugadores Cuadrado y Rodriguez, los índices no tienen que estar necesariamente ordenados. La serie se puede imprimir escribiendo su identificador.

# %%
seleccionColombia
# Out:
# 1        Ospina
# 2        Zapata
# 9        Falcao
# 11     Cuadrado
# 10    Rodriguez
# dtype: object

# %% [markdown]
# Una serie se puede generar sin conocer los índices y Pandas los generará automáticamente con valores desde cero hasta el tamaño de la lista menos uno. En el caso de la misma serie:

# %%
seleccionColombia = pd.Series(
    ['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'])
seleccionColombia
# Out:
# 0       Ospina
# 1       Zapata
# 2       Falcao
# 3     Cuadrado
# 4    Rodriguez
# dtype: object

# %% [markdown]
# ### Series desde Diccionarios
#
# Las series tambien pueden ser definidas desde diccionarios:

# %%
dict_selcol = {1:'Ospina', 2: 'Zapata', 9: 'Falcao', 11: 'Cuadrado', 10: 'Rodriguez'}
print(dict_selcol)
# Out:
# {1: 'Ospina', 2: 'Zapata', 9: 'Falcao', 11: 'Cuadrado', 10: 'Rodriguez'}

# %%
ser_selcol = pd.Series(dict_selcol)
ser_selcol.head()
# Out:
# 1        Ospina
# 2        Zapata
# 9        Falcao
# 11     Cuadrado
# 10    Rodriguez
# dtype: object

# %% [markdown]
# ### Usando los índices
#
# Los índices son la clave para entender cómo usar las Series. Pandas usa los nombres de los índices o sus números para permitir la búsqueda rápida de información (funcionan como una tabla hash o un diccionario).
#
# Para el ejemplo, vamos a crear 2 Series: ser1 y ser2

# %%
ser1 = pd.Series([10,20,30,40,50],index = ['Peru','Colombia', 'Germany','Spain', 'Japan'])

# %%
ser1
# Out:
# Peru        10
# Colombia    20
# Germany     30
# Spain       40
# Japan       50
# dtype: int64

# %%
#ser1[1]
ser1['Colombia']
# Out:
# 20

# %%
ser2 = pd.Series([1,2,3,4,5],index = ['Germany','Colombia','Colombia','Italy', 'Japan'])

# %%
ser2
# Out:
# Germany     1
# Colombia    2
# Colombia    3
# Italy       4
# Japan       5
# dtype: int64

# %%
ser2['Colombia']
# Out:
# Colombia    2
# Colombia    3
# dtype: int64

# %% [markdown]
# También, se pueden hacer operaciones entre Series:

# %%
ser1
# Out:
# Peru        10
# Colombia    20
# Germany     30
# Spain       40
# Japan       50
# dtype: int64

# %%
ser2
# Out:
# Germany     1
# Colombia    2
# Colombia    3
# Italy       4
# Japan       5
# dtype: int64

# %%
ser1 + ser2
# Out:
# Colombia    22.0
# Colombia    23.0
# Germany     31.0
# Italy        NaN
# Japan       55.0
# Peru         NaN
# Spain        NaN
# dtype: float64

# %%
ser1 / ser2
# Out:
# Colombia    10.000000
# Colombia     6.666667
# Germany     30.000000
# Italy             NaN
# Japan       10.000000
# Peru              NaN
# Spain             NaN
# dtype: float64

# %% [markdown]
# ## DataFrame
# Un DataFrame es una estructura de datos que almacena la información como una tabla ordenada por filas y columnas. Cada fila representa un objeto y cada columna la información correspondiente a una característica de los objetos.
#
# Un DataFrame también posee índices por cada fila, que pueden ser dados o generados automáticamente. Cada columna del DataFrame es una serie, donde el valor del índice corresponde con los valores de índice que tiene el DataFrame.
#
# Por medio de un diccionario vamos a crear un dataframe, donde las llaves son los nombres de las columnas y los valores son la lista de valores que tienen las características.
#
# Por ejemplo, para hacer un DataFrame con el equipo de fútbol anterior, pero agregando estatura y peso, podemos hacerlo de la siguiente manera:

# %%
dict_caracteristicas = {'apellido':['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'],
                       'altura':[183.0,187.0,177.0,179.0,180.0],
                       'peso':[80.0,82.0,72.0,72.0,75.0]}

seleccionColombia = pd.DataFrame(dict_caracteristicas,index=[1, 2, 9, 11, 10])

# %% [markdown]
# Al imprimir el DataFrame, podemos observar que su estructura es similar a la de un documento en Excel, donde el índice (que no tiene nombre de columna) es el número del jugador.

# %%
seleccionColombia
# Out:
#      apellido  altura  peso
# 1      Ospina   183.0  80.0
# 2      Zapata   187.0  82.0
# 9      Falcao   177.0  72.0
# 11   Cuadrado   179.0  72.0
# 10  Rodriguez   180.0  75.0

# %% [markdown]
# ### Acceso a los registros del DataFrame por el índice

# %% [markdown]
# En pandas podemos acceder a la fila por el índice de ésta. En el ejemplo anterior este índice era el número de la camiseta del jugador. Pero podría ser una fecha, una letra, etc.
#
# Si conocemos el índice simplemente lo usamos para ir directamente a la fila deseada.

# %%
seleccionColombia.loc[9]
# Out:
# apellido    Falcao
# altura         177
# peso            72
# Name: 9, dtype: object

# %%
seleccionColombia.iloc[2]
# Out:
# apellido    Falcao
# altura         177
# peso            72
# Name: 9, dtype: object

# %%
seleccionColombia.loc?

# %%
seleccionColombia.iloc?

# %% [markdown]
# Para agregar un nuevo jugador, se puede utilizar el índice, que en este caso es el número en el equipo y un arreglo representando todas sus características (apellido, altura y peso).
#
# NOTA: Las características tienen que estar en el mismo orden.

# %%
caract_jugador = ['Restrepo', 184.0, 80.0]
seleccionColombia.iloc[1] = caract_jugador

# %%
caract_jugador = ['Juan', 194.0, 90.0]
seleccionColombia.loc[200] = caract_jugador

# %% [markdown]
# Imprimiendo el DataFrame podemos ver el nuevo jugador.

# %%
seleccionColombia
# Out:
#       apellido  altura  peso
# 1       Ospina   183.0  80.0
# 2     Restrepo   184.0  80.0
# 9       Falcao   177.0  72.0
# 11    Cuadrado   179.0  72.0
# 10   Rodriguez   180.0  75.0
# 200       Juan   194.0  90.0

# %%
seleccionColombia.set_index?

# %% [markdown]
# ###Creando una columna nueva

# %%
seleccionColombia['IMC'] = seleccionColombia['peso'] / (seleccionColombia['altura'] ** 2) * 100

# %%
seleccionColombia
# Out:
#       apellido  altura  peso       IMC
# 1       Ospina   183.0  80.0  0.238884
# 2     Restrepo   184.0  80.0  0.236295
# 9       Falcao   177.0  72.0  0.229819
# 11    Cuadrado   179.0  72.0  0.224712
# 10   Rodriguez   180.0  75.0  0.231481
# 200       Juan   194.0  90.0  0.239133

# %%
seleccionColombia['Numero_partidos_jugados'] = [13, 7, 45, 20, 25, 13]

# %%
seleccionColombia
# Out:
#       apellido  altura  peso       IMC  Numero_partidos_jugados
# 1       Ospina   183.0  80.0  0.238884                       13
# 2     Restrepo   184.0  80.0  0.236295                        7
# 9       Falcao   177.0  72.0  0.229819                       45
# 11    Cuadrado   179.0  72.0  0.224712                       20
# 10   Rodriguez   180.0  75.0  0.231481                       25
# 200       Juan   194.0  90.0  0.239133                       13

# %% [markdown]
# ### Borrar Columna o Fila

# %%
seleccionColombia

# %%
df  = seleccionColombia.drop('IMC', axis=1)

# %%
df
# Out:
#       apellido  altura  peso  Numero_partidos_jugados
# 1       Ospina   183.0  80.0                       13
# 2     Restrepo   184.0  80.0                        7
# 9       Falcao   177.0  72.0                       45
# 11    Cuadrado   179.0  72.0                       20
# 10   Rodriguez   180.0  75.0                       25
# 200       Juan   194.0  90.0                       13

# %% [markdown]
# Si queremos eliminar una columna permanentemente también se puede usar:

# %%
del seleccionColombia['altura']

# %%
seleccionColombia
# Out:
#       apellido  peso       IMC  Numero_partidos_jugados
# 1       Ospina  80.0  0.238884                       13
# 2     Restrepo  80.0  0.236295                        7
# 9       Falcao  72.0  0.229819                       45
# 11    Cuadrado  72.0  0.224712                       20
# 10   Rodriguez  75.0  0.231481                       25
# 200       Juan  90.0  0.239133                       13

# %% [markdown]
# Si queremos saber cuales son las columnas actuales del data frame, usamos la propiedad 'columns' del objeto.

# %%
seleccionColombia.columns
# Out:
# Index(['apellido', 'peso', 'IMC', 'Numero_partidos_jugados'], dtype='object')

# %% [markdown]
# Si queremos conocer el indice del dataframe, con lo propiedad 'index' la conocemos.

# %%
seleccionColombia.index
# Out:
# Int64Index([1, 2, 9, 11, 10, 200], dtype='int64')

# %% [markdown]
# Para ordenar el dataframe se usa la función sort.

# %%
seleccionColombia.sort_index() #inplace=False por defecto
# Out:
#       apellido  peso       IMC  Numero_partidos_jugados
# 1       Ospina  80.0  0.238884                       13
# 2     Restrepo  80.0  0.236295                        7
# 9       Falcao  72.0  0.229819                       45
# 10   Rodriguez  75.0  0.231481                       25
# 11    Cuadrado  72.0  0.224712                       20
# 200       Juan  90.0  0.239133                       13

# %%
seleccionColombia.sort_index?

# %%
seleccionColombia.sort_values?

# %% [markdown]
# ## Datos faltantes: rellenar valores NaN con algo más
#
# En algunas ocaciones vamos a tener valor inválidos en nuestros dataframes. Estos valores son un problema al momento de hacer cálculos numéricos o tomar estadísticas.
#
# Para esto es necesario dejar fuera del dataframe estos campos.
#
# En las siguientes líneas usted verá como se eliminan estos valores.

# %%
df = pd.DataFrame({'col1':[1, 2, 3, np.nan],
                   'col2':[np.nan, 555, 666, 444],
                   'col3':['abc', 'def', 'ghi', 'xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %% [markdown]
# **Hallar valores NULL o verificarlos**

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False   True  False
# 1  False  False  False
# 2  False  False  False
# 3   True  False  False

# %%
df.fillna('VALOR') # inplace=False por defecto
# Out:
#     col1   col2 col3
# 0      1  VALOR  abc
# 1      2    555  def
# 2      3    666  ghi
# 3  VALOR    444  xyz

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna?

# %%
# En este caso, se usará la media de los valores de la Columna 2 para llenar sus valores faltantes:
df['col2'].fillna(value=df['col2'].mean(), inplace=True)

# %%
df['col1'].fillna(value=df['col1'].mean(), inplace=False)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# Name: col1, dtype: float64

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
# Eliminar filas con valores NaN
df.dropna(axis=0)
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi

# %%
df.dropna?

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.isna()
# Out:
#     col1   col2   col3
# 0  False   True  False
# 1  False  False  False
# 2  False  False  False
# 3   True  False  False

# %%
df.isna().any() # retrona las columnas con valores faltantes en True
# Out:
# col1     True
# col2     True
# col3    False
# dtype: bool

# %%
df.isna().sum() # retorna la cantidad de valores faltantes por columna
# Out:
# col1    1
# col2    1
# col3    0
# dtype: int64

# %%
import missingno as msno
#https://github.com/ResidentMario/missingno
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %% [markdown]
# # 2. Acceso a datos

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# Pandas permite leer archivos en diferentes formatos, como txt, csv y excel. En este ejemplo se leerá un dataset correspondiente a la información nutricional de un listado de 80 cereales. El dataset puede ser descargado en el siguiente enlace (botón Downloads):
#
# https://www.kaggle.com/crawford/80-cereals
#
# Como el formato es .csv, se lee usando la función de pandas read_csv usando como parámetro la dirección del archivo. Si el archivo está en la misma carpeta del notebook, se puede usar solo su nombre.

# %%
url="https://drive.google.com/uc?export=download&id=1cVDBakqy6tSwCwgzAtf08hNvjHk8a6hv"
df_cereals = pd.read_csv(url)

# %% [markdown]
# Si quiere conocer más formatos de entrada/salida como json, excel, hdf5, SQL, etc. Puede ir a la siguiente URL:
#
# https://pandas.pydata.org/pandas-docs/stable/io.html

# %% [markdown]
# ### Funciones para revisión de los datos
# Lo primero que haremos es revisar las propiedades que tienen las columnas del DataFrame. Como el nombre de las columnas y sus tipos:

# %%
df_cereals.columns
# Out:
# Index(['Cereal Name', 'Manufacturer', 'Type', 'Calories', 'Protein (g)', 'Fat',
#        'Sodium', 'Dietary Fiber', 'Carbs', 'Sugars', 'Display Shelf',
#        'Potassium', 'Vitamins and Minerals', 'Serving Size Weight',
#        'Cups per Serving'],
#       dtype='object')

# %% [markdown]
# La función Info nos da un resumen del DataFrame y sus datos.

# %%
df_cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cereal Name            74 non-null     object
#  1   Manufacturer           74 non-null     object
#  2   Type                   74 non-null     object
#  3   Calories               74 non-null     int64
#  4   Protein (g)            74 non-null     int64
#  5   Fat                    74 non-null     int64
#  6   Sodium                 74 non-null     int64
#  7   Dietary Fiber          74 non-null     float64
#  8   Carbs                  74 non-null     float64
#  9   Sugars                 74 non-null     int64
#  10  Display Shelf          74 non-null     int64
#  11  Potassium              74 non-null     int64
#  12  Vitamins and Minerals  74 non-null     int64
#  13  Serving Size Weight    74 non-null     float64
#  14  Cups per Serving       74 non-null     float64
# dtypes: float64(4), int64(8), object(3)
# memory usage: 8.8+ KB

# %% [markdown]
# La función dtypes sólo nos indica los tipo de datos de las columnas.

# %%
df_cereals.dtypes
# Out:
# Cereal Name               object
# Manufacturer              object
# Type                      object
# Calories                   int64
# Protein (g)                int64
# Fat                        int64
# Sodium                     int64
# Dietary Fiber            float64
# Carbs                    float64
# Sugars                     int64
# Display Shelf              int64
# Potassium                  int64
# Vitamins and Minerals      int64
# Serving Size Weight      float64
# Cups per Serving         float64
# dtype: object

# %% [markdown]
# Se puede observar que Pandas es capaz de inferir el tipo de columna a partir de los datos.
#
# Para darle un vistazo inicial al DataFrame se puede utilizar la función head del DataFrame, que tiene como parámetro el número de filas que queremos observar, comenzando en orden por la primera.

# %%
df_cereals.head(10)
# Out:
#                  Cereal Name  ... Cups per Serving
# 0                  100%_Bran  ...             0.33
# 1          100%_Natural_Bran  ...            -1.00
# 2                   All-Bran  ...             0.33
# 3  All-Bran_with_Extra_Fiber  ...             0.50
# 4             Almond_Delight  ...             0.75
# 5    Apple_Cinnamon_Cheerios  ...             0.75
# 6                Apple_Jacks  ...             1.00
# 7                    Basic_4  ...             0.75
# 8                  Bran_Chex  ...             0.67
# 9                Bran_Flakes  ...             0.67
#
# [10 rows x 15 columns]

# %%
df_cereals.tail()
# Out:
#             Cereal Name    Manufacturer  ... Serving Size Weight  Cups per Serving
# 69              Triples   General Mills  ...                 1.0              0.75
# 70                 Trix   General Mills  ...                 1.0              1.00
# 71           Wheat_Chex  Ralston Purina  ...                 1.0              0.67
# 72             Wheaties   General Mills  ...                 1.0              1.00
# 73  Wheaties_Honey_Gold   General Mills  ...                 1.0              0.75
#
# [5 rows x 15 columns]

# %% [markdown]
# La función describe nos entrega las estadísticas descriptivas que nos permite conocer la tendencia de los datos, dispersión, dictribución, valores nulos y otros más.

# %%
df_cereals['Calories'].describe()
# Out:
# count     74.000000
# mean     105.540541
# std       18.442201
# min       50.000000
# 25%      100.000000
# 50%      110.000000
# 75%      110.000000
# max      160.000000
# Name: Calories, dtype: float64

# %%
df_cereals['Manufacturer'].describe()
# Out:
# count           74
# unique           7
# top       Kelloggs
# freq            23
# Name: Manufacturer, dtype: object

# %%
df_cereals.describe?

# %% [markdown]
# Para una descripción rápida se puede utilizar la función describe para todo el dataframe:

# %%
df_cereals.describe(include='all')
# Out:
#          Cereal Name Manufacturer  ... Serving Size Weight  Cups per Serving
# count             74           74  ...           74.000000         74.000000
# unique            74            7  ...                 NaN               NaN
# top     Golden_Crisp     Kelloggs  ...                 NaN               NaN
# freq               1           23  ...                 NaN               NaN
# mean             NaN          NaN  ...            1.027432          0.629054
# std              NaN          NaN  ...            0.151260          0.576843
# min              NaN          NaN  ...            0.500000         -1.000000
# 25%              NaN          NaN  ...            1.000000          0.670000
# 50%              NaN          NaN  ...            1.000000          0.750000
# 75%              NaN          NaN  ...            1.000000          1.000000
# max              NaN          NaN  ...            1.500000          1.500000
#
# [11 rows x 15 columns]

# %% [markdown]
# Otras funciones útiles:

# %%
df_cereals.count()
# Out:
# Cereal Name              74
# Manufacturer             74
# Type                     74
# Calories                 74
# Protein (g)              74
# Fat                      74
# Sodium                   74
# Dietary Fiber            74
# Carbs                    74
# Sugars                   74
# Display Shelf            74
# Potassium                74
# Vitamins and Minerals    74
# Serving Size Weight      74
# Cups per Serving         74
# dtype: int64

# %%
df_cereals['Manufacturer'].unique()
# Out:
# array(['Nabisco', 'Quaker Oats', 'Kelloggs', 'Ralston Purina',
#        'General Mills', 'Post', 'American Home Food Products'],
#       dtype=object)

# %%
df_cereals['Manufacturer'].nunique()
# Out:
# 7

# %%
df_cereals['Manufacturer'].value_counts()
# Out:
# Kelloggs                       23
# General Mills                  22
# Quaker Oats                     8
# Post                            8
# Nabisco                         6
# Ralston Purina                  6
# American Home Food Products     1
# Name: Manufacturer, dtype: int64

# %% [markdown]
# ## Indexación
# En Pandas la indexación es similar a la que se tiene en Numpy. El resultado de obtener resultados por indexación es otro DataFrame correspondiente a ciertas filas del DataFrame original.
#
# ### Obtención de filas por índice
# Un ejemplo es acceder a una fila por medio de la función iloc. En la siguiente celda se selecciona el cereal con índice 7.

# %%
df_cereals.iloc[7]
# Out:
# Cereal Name                    Basic_4
# Manufacturer             General Mills
# Type                                 C
# Calories                           130
# Protein (g)                          3
# Fat                                  2
# Sodium                             210
# Dietary Fiber                        2
# Carbs                               18
# Sugars                               8
# Display Shelf                        3
# Potassium                          100
# Vitamins and Minerals               25
# Serving Size Weight               1.33
# Cups per Serving                  0.75
# Name: 7, dtype: object

# %% [markdown]
# ### Obtención de valores por columna
# Para obtener toda la información de una columna, se puede acceder al DataFrame como un diccionario, en donde la llave es la columna a la que queremos acceder.

# %%
info_calories = df_cereals['Calories']

# %% [markdown]
# Veamos que si usamos el acceso con un corchete cuadrado, nos retorna un objeto tipo series.

# %%
type(info_calories)
# Out:
# pandas.core.series.Series

# %%
info_calories
# Out:
# 0      70
# 1     120
# 2      70
# 3      50
# 4     110
#      ...
# 69    110
# 70    110
# 71    100
# 72    100
# 73    110
# Name: Calories, Length: 74, dtype: int64

# %% [markdown]
# En cambio si usamos doble corchete, nos retorna un dataframe con la columna.

# %%
df_cereals[['Calories']]
# Out:
#     Calories
# 0         70
# 1        120
# 2         70
# 3         50
# 4        110
# ..       ...
# 69       110
# 70       110
# 71       100
# 72       100
# 73       110
#
# [74 rows x 1 columns]

# %% [markdown]
# La información de columna se obtiene en el mismo orden que en el DataFrame original. Al imprimirlo, podemos ver en la primera columna el valor del índice y en la segunda el valor de la columna seleccionada.

# %%
print(info_calories[0:10])
# Out:
# 0     70
# 1    120
# 2     70
# 3     50
# 4    110
# 5    110
# 6    110
# 7    130
# 8     90
# 9     90
# Name: Calories, dtype: int64

# %% [markdown]
# Se pueden seleccionar más de una columna del DataFrame a la vez.

# %%
df_cereals[['Calories','Sugars']]
# Out:
#     Calories  Sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 69       110       3
# 70       110      12
# 71       100       3
# 72       100       3
# 73       110       8
#
# [74 rows x 2 columns]

# %% [markdown]
# ### Obtención de valores usando condiciones
# Con Pandas, se pueden seleccionar columnas cuyas características cumplan ciertas condiciones. Por ejemplo, los cereales con menos de 100 calorias. Para ello se hace la selección de la columna, se evalua la condición con ésta y luego se selecciona del DataFrame el segmento que cumple la condición de la siguiente manera:

# %%
#Seleccion de columna: df_cereals['calories']
#Condicion sobre esa columna: df_cereals['calories'] < 100
#Seleccion de fragmento de dataframe que cumple la condicion:
    #df_cereals[df_cereals['calories'] < 100]
less_100_cal = df_cereals[df_cereals['Calories'] < 100]

# %%
less_100_cal
# Out:
#                   Cereal Name  ... Cups per Serving
# 0                   100%_Bran  ...             0.33
# 2                    All-Bran  ...             0.33
# 3   All-Bran_with_Extra_Fiber  ...             0.50
# 8                   Bran_Chex  ...             0.67
# 9                 Bran_Flakes  ...             0.67
# 47          Nutri-grain_Wheat  ...            -1.00
# 51                Puffed_Rice  ...             1.00
# 52               Puffed_Wheat  ...            -1.00
# 57             Raisin_Squares  ...             0.50
# 60             Shredded_Wheat  ...            -1.00
# 61     Shredded_Wheat_'n'Bran  ...             0.67
# 62  Shredded_Wheat_spoon_size  ...             0.67
# 65    Strawberry_Fruit_Wheats  ...            -1.00
#
# [13 rows x 15 columns]

# %% [markdown]
# Las condiciones se pueden mezclar usando operadores lógicos, por ejemplo cereales con menos de 100 calorias y sin grasa (valor 0 en fat).

# %%
condition_calories = df_cereals['Calories'] < 100
condition_fat = df_cereals['Fat'] == 0
less_100_cal_and_fat = df_cereals[condition_calories & condition_fat]

# %%
condition_calories
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Name: Calories, Length: 74, dtype: bool

# %%
less_100_cal_and_fat.describe()
# Out:
#         Calories  Protein (g)  ...  Serving Size Weight  Cups per Serving
# count  10.000000    10.000000  ...            10.000000         10.000000
# mean   77.000000     2.500000  ...             0.883000          0.001000
# std    18.885621     0.849837  ...             0.208702          0.872206
# min    50.000000     1.000000  ...             0.500000         -1.000000
# 25%    57.500000     2.000000  ...             0.872500         -1.000000
# 50%    90.000000     2.500000  ...             1.000000          0.500000
# 75%    90.000000     3.000000  ...             1.000000          0.670000
# max    90.000000     4.000000  ...             1.000000          1.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# Teniendo en cuenta que el resultado de la indexación también es un DataFrame, se pueden hacer operaciones similares sobre el resultado, que en este caso tiene el identificador less_100_cal_and_fat.

# %%
less_100_cal_and_fat.head(10)
# Out:
#                   Cereal Name  ... Cups per Serving
# 3   All-Bran_with_Extra_Fiber  ...             0.50
# 9                 Bran_Flakes  ...             0.67
# 47          Nutri-grain_Wheat  ...            -1.00
# 51                Puffed_Rice  ...             1.00
# 52               Puffed_Wheat  ...            -1.00
# 57             Raisin_Squares  ...             0.50
# 60             Shredded_Wheat  ...            -1.00
# 61     Shredded_Wheat_'n'Bran  ...             0.67
# 62  Shredded_Wheat_spoon_size  ...             0.67
# 65    Strawberry_Fruit_Wheats  ...            -1.00
#
# [10 rows x 15 columns]

# %% [markdown]
# ### Ejemplos de operaciones sobre DataFrames

# %% [markdown]
# Como se vio al usar la función describe, con el DataFrame se pueden hacer operaciones matemáticas, como hallar la media y desviación estándar. En este caso vamos a hallar la media de calificaciones de los cereales que tienen menos de 100 calorias y no tienen grasa. La operación de media se calcula sobre todas las columnas.

# %%
less_100_cal_and_fat.mean()
# Out:
# Calories                  77.000
# Protein (g)                2.500
# Fat                        0.000
# Sodium                    53.500
# Dietary Fiber              3.800
# Carbs                     14.700
# Sugars                     1.800
# Display Shelf              2.300
# Potassium                123.000
# Vitamins and Minerals     12.500
# Serving Size Weight        0.883
# Cups per Serving           0.001
# dtype: float64

# %% [markdown]
# La desviación estándar sobre el rating se puede calcular de la siguiente manera.

# %%
less_100_cal_and_fat.std()
# Out:
# Calories                 18.885621
# Protein (g)               0.849837
# Fat                       0.000000
# Sodium                   84.460707
# Dietary Fiber             3.852849
# Carbs                     3.831159
# Sugars                    2.529822
# Display Shelf             0.948683
# Potassium                86.769170
# Vitamins and Minerals    13.176157
# Serving Size Weight       0.208702
# Cups per Serving          0.872206
# dtype: float64

# %% [markdown]
# ### Multi-Indices
#
# Los dataframes pueden tener varios índices usando la funcionalidad de MultiIndex. Estos se pueden crear a partir de una lista de tuplas, con el método from_tuples, donde cada tupla contiene los nombres de cada columna o a partir de una combinación entre varias tuplas con el método from_product

# %%
columnas = pd.MultiIndex.from_tuples([('A', 'positivo'), ('B', 'positivo'), 
                                     ('A', 'negativo'), ('B', 'negativo'), 
                                     ('O', 'positivo')], 
                                     names=['tipo', 'Rh'])

# %%
columnas
# Out:
# MultiIndex([('A', 'positivo'),
#             ('B', 'positivo'),
#             ('A', 'negativo'),
#             ('B', 'negativo'),
#             ('O', 'positivo')],
#            names=['tipo', 'Rh'])

# %% [markdown]
# Ahora se crea el Indice

# %%
indices = pd.MultiIndex.from_product([('menor', 'adulto'),('hombre', 'mujer')], 
                                   names=['edad', 'sexo'])
df = pd.DataFrame(np.random.randn(4,5), columns=columnas, index=indices)
df
# Out:
# tipo                  A         B         A         B         O
# Rh             positivo  positivo  negativo  negativo  positivo
# edad   sexo
# menor  hombre  0.730336 -0.005885 -0.414293  0.359822  0.178660
#        mujer  -0.392126 -0.012770 -0.257289 -1.452085 -0.413698
# adulto hombre  1.627568  0.529444  0.647870  0.480995 -0.717703
#        mujer   0.148519 -0.195523  0.420208  0.222370 -1.327247

# %% [markdown]
# Para obtener información de las columnas de otros niveles, se debe referir primero la columna de primer nivel y luego a las de los niveles siguientes, en órden jerárquico.

# %%
df['B', 'positivo']
# Out:
# edad    sexo
# menor   hombre   -0.005885
#         mujer    -0.012770
# adulto  hombre    0.529444
#         mujer    -0.195523
# Name: (B, positivo), dtype: float64

# %% [markdown]
# La función 'xs' (cross-section) retorna la sección transversal de un DataFrame que usa multi-índices.
# Por ejemplo, es útil cuando queremos filtrar todos los elementos de un determinado "sexo" en el DataFrame anterior, independientemente de su "edad".

# %%
# En este caso seleccionamos el Num=1
df.xs('hombre',level='sexo')
# Out:
# tipo           A         B         A         B         O
# Rh      positivo  positivo  negativo  negativo  positivo
# edad
# menor   0.730336 -0.005885 -0.414293  0.359822  0.178660
# adulto  1.627568  0.529444  0.647870  0.480995 -0.717703

# %% [markdown]
# # 3. Manipulando Data Frames

# %% [markdown]
# ## Combinando DataFrames
#
# Hay 3 maneras de combinar DataFrames:
# * Concatenar (concat)
# * Fusionar (merge)
# * Unir (join)

# %% [markdown]
# _____
# **DataFrames de ejemplo**

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
print(df1,'\n')
print(df2,'\n')
print(df3)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
#
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ### Concatenar (concat)
#
# La concatenación básicamente pega DataFrames, uno después de otro. Hay que tener en cuenta que las dimensiones deben coincidir a lo largo del eje con el que se está concatenando.
#
# Puede usar **pd.concat** y pasar una lista de DataFrames para concatenarlos:

# %%
pd.concat([df1, df2, df3.rename(columns={'D':'E'})])
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8  NaN   D8
# 9    A9   B9   C9  NaN   D9
# 10  A10  B10  C10  NaN  D10
# 11  A11  B11  C11  NaN  D11

# %%
df_c = pd.concat([df1, df2, df3], axis=1)

# %%
df_c = pd.concat([df1, 
                  df2.rename(columns={'A':'A2', 'B':'B2', 'C':'C2', 'D':'D2'}), 
                  df3.rename(columns={'A':'A3', 'B':'B3', 'C':'C3', 'D':'D3'})], axis=1)    # axis=1 cooncatena a lo largo de las columnas, llenando las celdas desconocidad con NaN

# %%
df_c
# Out:
#       A    B    C    D   A2   B2   C2   D2   A3   B3   C3   D3
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
df_c.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'A', 'B', 'C', 'D', 'A', 'B', 'C', 'D'], dtype='object')

# %%
df_c.drop('A', axis=1)
# Out:
#       B    C    D    B    C    D    B    C    D
# 0    B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN
# 1    B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN
# 2    B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN
# 3    B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN   B4   C4   D4  NaN  NaN  NaN
# 5   NaN  NaN  NaN   B5   C5   D5  NaN  NaN  NaN
# 6   NaN  NaN  NaN   B6   C6   D6  NaN  NaN  NaN
# 7   NaN  NaN  NaN   B7   C7   D7  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  B11  C11  D11

# %%
df2.rename(columns={'A':'A2', 'B':'B2', 'C':'C2'})
# Out:
#    A2  B2  C2   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1.append?

# %% [markdown]
# ___

# %% [markdown]
# ### Fusionar (merge)
#
# La función **merge** permite fusionar DataFrames utilizando una lógica similar a la combinación de Tablas SQL. Por ejemplo:

# %%
izq = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
der = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
izq
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
der
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(izq, der)
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(izq, der, on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge?

# %% [markdown]
# Otro ejemplo más completo:

# %%
izq = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
der = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
izq
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
der
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(izq, der, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# #### Argumento 'how'
#
# El método merge recibe el argumento 'how'. Éste especifica cómo determinar qué claves se incluirán en la tabla resultante. Si una combinación de dichas llaves no aparece en las tablas izquierda o derecha, los valores en la tabla fusionada serán NaN.
#
# Aquí hay un resumen de las opciones de 'how' y sus nombres equivalentes en SQL:
#
# 	PANDAS	SQL					DESCRIPCIÓN
# 	inner	INNER JOIN			Usa la intersection de las llaves de ambos dataframes * Por defecto
#     left	LEFT OUTER JOIN		Sólo usa las llaves del dataframe izquierdo
# 	right	RIGHT OUTER JOIN	Sólo usa las llaves del dataframe derecho
# 	outer	FULL OUTER JOIN		Usa la unión de las llaves de ambos dataframes
#
# ![](https://drive.google.com/uc?export=view&id=1k9cAel1FLYgou8ITAeqKE3vOIFBJydQB)
#
#
# ![wget](https://drive.google.com/uc?export=view&id=1wmJo-FJnofniKEkF-3RRR-Mk9IVuc-Nx)

# %%
pd.merge(izq, der, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(izq, der, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
pd.merge( izq, der[['key1','key2','D']], how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   D
# 0   K0   K0   A0   B0  D0
# 1   K1   K0   A2   B2  D1
# 2   K1   K0   A2   B2  D2
# 3   K2   K0  NaN  NaN  D3

# %% [markdown]
# ### Unión (join)
#
# El join es un método para combinar las columnas de dos DataFrames indexados de forma diferente en un solo DataFrame de resultados.
#
# En vez de columnas como en el merge, en el join se utilizan los índices de los DataFrames para hacer la combinación.

# %%
izq = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

der = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
izq
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
der
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
izq.join(der)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
izq.join(der, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
izq.join(der, how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
izq.join?

# %% [markdown]
# ## Función Apply

# %%
df = pd.DataFrame(np.random.randn(4,5), columns=['A', 'B', 'C', 'D', 'E'], index=[100, 101, 102, 110])
df
# Out:
#             A         B         C         D         E
# 100 -0.367812  0.075967 -0.635507 -2.195556  1.412629
# 101 -0.603602  0.464516 -0.473830 -1.608278  0.692090
# 102  0.145562 -1.553959 -0.672351 -0.857640 -0.972369
# 110  1.758551 -1.516131  0.774496 -1.911697  0.254596

# %%
df['A'].sum()
# Out:
# 0.932699973592949

# %%
def times2(x):
    return x*2

# %%
df['A']
# Out:
# 100   -0.367812
# 101   -0.603602
# 102    0.145562
# 110    1.758551
# Name: A, dtype: float64

# %%
df['A'].apply(times2)
# Out:
# 100   -0.735623
# 101   -1.207203
# 102    0.291124
# 110    3.517103
# Name: A, dtype: float64

# %%
df['B']
# Out:
# 100    0.075967
# 101    0.464516
# 102   -1.553959
# 110   -1.516131
# Name: B, dtype: float64

# %%
# Apply es muy útil y puede ser usado también con expresiones lambda

df['B'].apply(lambda x: x*2)
# Out:
# 100    0.151934
# 101    0.929031
# 102   -3.107919
# 110   -3.032261
# Name: B, dtype: float64

# %%
# También se puede usar con funciones predeterminadas como abs, len, ...
df['B'].apply(lambda x: abs(x)*2)
# Out:
# 100    0.151934
# 101    0.929031
# 102    3.107919
# 110    3.032261
# Name: B, dtype: float64

# %% [markdown]
# ## Tablas Pivote

# %%
data = {'A':['llave 1','llave 1','llave 1','llave 2','llave 2','llave 2'],
     'B':['uno','uno','dos','dos','uno','uno'],
       'C':['categoria 1','categoria 2','categoria 1','categoria 2','categoria 1','categoria 2'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#          A    B            C  D
# 0  llave 1  uno  categoria 1  1
# 1  llave 1  uno  categoria 2  3
# 2  llave 1  dos  categoria 1  2
# 3  llave 2  dos  categoria 2  5
# 4  llave 2  uno  categoria 1  4
# 5  llave 2  uno  categoria 2  1

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])
# Out:
# C            categoria 1  categoria 2
# A       B
# llave 1 dos          2.0          NaN
#         uno          1.0          3.0
# llave 2 dos          NaN          5.0
#         uno          4.0          1.0

# %%
df.pivot_table?

# %% [markdown]
# Otro ejemplo:

# %%
df = pd.DataFrame({"A": ["llave 1", "llave 1", "llave 1", "llave 1", "llave 1",
                         "llave 2", "llave 2", "llave 2", "llave 2"],
                    "B": ["uno", "uno", "uno", "dos", "dos",
                          "uno", "uno", "uno", "dos"],
                    "C": ["mediano", "grande", "grande", "mediano",
                          "mediano", "grande", "mediano", "mediano", "grande"],
                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7]})
df
# Out:
#          A    B        C  D
# 0  llave 1  uno  mediano  1
# 1  llave 1  uno   grande  2
# 2  llave 1  uno   grande  2
# 3  llave 1  dos  mediano  3
# 4  llave 1  dos  mediano  3
# 5  llave 2  uno   grande  4
# 6  llave 2  uno  mediano  5
# 7  llave 2  uno  mediano  6
# 8  llave 2  dos   grande  7

# %%
table = df.pivot_table(values='D', index=['A', 'B'],
                     columns=['C'], aggfunc=np.sum)
table
# Out:
# C            grande  mediano
# A       B
# llave 1 dos     NaN      6.0
#         uno     4.0      1.0
# llave 2 dos     7.0      NaN
#         uno     4.0     11.0

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Agrupaciones y agregaciones: Groupby
#
# El método groupby permite agrupar filas de datos basándose en el valor de una columna, y llamar a funciones de agregación sobre los datos: suma, conteo, promedio, ...
#
# ![](https://drive.google.com/uc?export=view&id=1dxdpTG6ZJovzaxzerMFLPIv8daDlfFvV)

# %%
# Datos para crear el dataframe
data = {'Empresa':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Persona':['Ana', 'Carlos', 'Manuela', 'Vanessa', 'Camilo', 'Sara'],
       'Ventas':[200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Empresa  Persona  Ventas
# 0    GOOG      Ana     200
# 1    GOOG   Carlos     120
# 2    MSFT  Manuela     340
# 3    MSFT  Vanessa     124
# 4      FB   Camilo     243
# 5      FB     Sara     350

# %% [markdown]
# **Ahora usaremos el método .groupby() para agrupar las filas basándose en los datos de una columna. Por ejemplo, el nombre de la compañía. Esto creará un objeto DataFrameGroupBy.**

# %%
df.groupby('Empresa')

# %% [markdown]
# Se puede guardar este objeto como una nueva variable:

# %%
by_empresa = df.groupby("Empresa")

# %% [markdown]
# Y luego llamar funciones de agregación sobre este objeto.
# Las funciones de agregación tendrán efecto sobre las columnas que sea posible, es decir, si son funciones numéricas sólo tendrán efecto sobre los datos numéricos:

# %%
by_empresa.mean()
# Out:
#          Ventas
# Empresa
# FB        296.5
# GOOG      160.0
# MSFT      232.0

# %%
df.groupby('Empresa').mean()
# Out:
#          Ventas
# Empresa
# FB        296.5
# GOOG      160.0
# MSFT      232.0

# %% [markdown]
# Más ejemplos de funciones de agregación:

# %%
by_empresa.std()
# Out:
#              Ventas
# Empresa
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
# En este caso la función min también tiene efecto sobre los datos textuales; se devuelve el menor valor de la cadena
# del nombre de las personas (ordenado lexicograficamente). Nótese que el valor de las ventas, no corresponde al de la persona, 
# sino al valor menor de ventas de la empresa. 

by_empresa.min()
# Out:
#          Persona  Ventas
# Empresa
# FB        Camilo     243
# GOOG         Ana     120
# MSFT     Manuela     124

# %%
by_empresa.max()
# Out:
#          Persona  Ventas
# Empresa
# FB          Sara     350
# GOOG      Carlos     200
# MSFT     Vanessa     340

# %%
by_empresa.count()
# Out:
#          Persona  Ventas
# Empresa
# FB             2       2
# GOOG           2       2
# MSFT           2       2

# %%
by_empresa.sum()
# Out:
#          Ventas
# Empresa
# FB          593
# GOOG        320
# MSFT        464

# %%
# Podemos acceder a un solo valor:

by_empresa.sum().loc['FB']
# Out:
# Ventas    593
# Name: FB, dtype: int64

# %%
# Muchas veces no se crea un objeto groupby de forma explícita, sino que se utiliza directamente:

df.groupby('Empresa').sum().loc['FB']
# Out:
# Ventas    593
# Name: FB, dtype: int64

# %%
# El metodo describe es útil para presentar mucha información acerca del dataframe:

by_empresa.describe()
# Out:
#         Ventas
#          count   mean         std    min     25%    50%     75%    max
# Empresa
# FB         2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG       2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT       2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_empresa.describe().transpose()
# Out:
# Empresa               FB        GOOG        MSFT
# Ventas count    2.000000    2.000000    2.000000
#        mean   296.500000  160.000000  232.000000
#        std     75.660426   56.568542  152.735065
#        min    243.000000  120.000000  124.000000
#        25%    269.750000  140.000000  178.000000
#        50%    296.500000  160.000000  232.000000
#        75%    323.250000  180.000000  286.000000
#        max    350.000000  200.000000  340.000000

# %%
by_empresa.describe().transpose()['GOOG']
# Out:
# Ventas  count      2.000000
#         mean     160.000000
#         std       56.568542
#         min      120.000000
#         25%      140.000000
#         50%      160.000000
#         75%      180.000000
#         max      200.000000
# Name: GOOG, dtype: float64
